# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from pprint import pprint
from lxml import html
from lxml.html import fromstring
import urllib.request
from urllib.request import urlopen
import random
import re
import scrapy


pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
URLs=["https://www.pokemon.com/us/play-pokemon/worlds/2014/teams/masters/","https://www.pokemon.com/us/play-pokemon/worlds/2014/teams/senior/", "https://www.pokemon.com/us/play-pokemon/worlds/2014/teams/junior/",
      "https://www.pokemon.com/us/play-pokemon/worlds/2015/teams/masters/", "https://www.pokemon.com/us/play-pokemon/worlds/2015/teams/seniors/", "https://www.pokemon.com/us/play-pokemon/worlds/2015/teams/juniors/",
      "https://www.pokemon.com/us/play-pokemon/worlds/2016/teams/masters/", "https://www.pokemon.com/us/play-pokemon/worlds/2016/teams/seniors/", "https://www.pokemon.com/us/play-pokemon/worlds/2016/teams/juniors/",
      "https://www.pokemon.com/us/play-pokemon/worlds/2017/vgc-masters/", "https://www.pokemon.com/us/play-pokemon/worlds/2017/vgc-seniors/", "https://www.pokemon.com/us/play-pokemon/worlds/2017/vgc-juniors/",
      "https://www.pokemon.com/us/play-pokemon/worlds/2018/vgc-masters/", "https://www.pokemon.com/us/play-pokemon/worlds/2018/vgc-seniors/", "https://www.pokemon.com/us/play-pokemon/worlds/2018/vgc-juniors/",
      "https://www.pokemon.com/us/play-pokemon/worlds/2019/vgc-masters/", "https://www.pokemon.com/us/play-pokemon/worlds/2019/vgc-senior/", "https://www.pokemon.com/us/play-pokemon/worlds/2019/vgc-junior/"]

# %%
url = "https://www.pokemon.com/us/play-pokemon/worlds/2014/teams/masters/"
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")
print(soup)
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en">
# <head>
# <meta charset="utf-8"/>
# ...

# %%
content = soup.find_all("div", {"class":"row-wrapper"})

# %%
content
# Out:
# [<div class="row-wrapper">
#  <div class="pokemon left" data-link="/us/pokedex/417">
#  <div class="banner banner-yellow dog-ear-tl pokemon-header no-border-radius-bottom">
#  <h3>Pachirisu</h3>
#  <p class="forme">
#  </p>
#  </div>
#  <div class="pokemon-body section">
#  <div class="column-6 push-1">
#  <div class="moves">
#  <div class="label color-text color-orange">Moves:</div>
#  <ul>
#  <li>Nuzzle</li>
#  <li>Follow Me</li>
#  <li>Super Fang</li>
#  <li>Protect</li>
#  </ul>
#  </div>
#  </div>
#  <div class="column-6 push-7">
#  <div class="nature">
#  <div class="label color-text color-orange">Nature:</div>
#  <ul>
#  <li>Impish</li>
#  </ul>
#  </div>
#  <div class="held-item">
#  <div class="label color-text color-orange">Held Item:</div>
#  <ul>
#  <li>Sitrus Berry</li>
#  </ul>
#  </div>
#  <div class="ability">
#  <div class="label color-text color-orange">Ability:</div>
#  <ul>
#  <li>Volt Absorb</li>
#  </ul>
#  </div>
#  </div>
#  </div>
#  </div>
# ...

# %%
name = [name for tag in content.find_all("h3")]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-c75cf3a9e308> in <module>
# ----> 1 name = [name for tag in content.find_all("h3")]
#
# ~\Anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    2079         """Raise a helpful exception to explain a common code fix."""
#    2080         raise AttributeError(
# -> 2081             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2082         )
#
# AttributeError: ResultSet object has no attribute 'find_all'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
pokémon_list = []
    
for pokémon in content:
    name = earthquake.find("td", {"class": "tabev6"}).find("a").text.split()
    latitude_degree, longitude_degree = earthquake.find_all("td", {"class": "tabev1"})
    latitude_cardinality, longitude_cardinality, magnitude = earthquake.find_all("td", {"class": "tabev2"})
    latitude = f"{latitude_degree.text.strip()} {latitude_cardinality.text.strip()}"
    longitude = f"{longitude_degree.text.strip()} {longitude_cardinality.text.strip()}"
    region = earthquake.find('td', {'class': 'tb_region'}).text.strip()
    results = [date, time, latitude, longitude, region]
    pokémon_list.append(results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-8ae812152cff> in <module>
#       2
#       3 for pokémon in content:
# ----> 4     date, time = earthquake.find("td", {"class": "tabev6"}).find("a").text.split()
#       5     latitude_degree, longitude_degree = earthquake.find_all("td", {"class": "tabev1"})
#       6     latitude_cardinality, longitude_cardinality, magnitude = earthquake.find_all("td", {"class": "tabev2"})
#
# NameError: name 'earthquake' is not defined

# %%
colnames = ["Name", "Move 1", "Move 2", "Move 3", "Move 4", "Nature", "Held Item", "Ability"]

earthquakeDF = pd.DataFrame(pokémon_list, columns = colnames)

earthquakeDF
